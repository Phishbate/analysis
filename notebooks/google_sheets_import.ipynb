# %%
# 1. Authorizing google colab
from google.colab import auth
auth.authenticate_user()

# 2. credentials for google sheets
import gspread
from google.auth import default
creds, _ = default()

# 3. authotizing the connection
gc = gspread.authorize(creds)

#4. Connecting
worksheet = gc.open('Cyber Security Risk Assessment (Responses)').sheet1

#5. Exporting data to get_all_values gives a list of rows.
rows = worksheet.get_all_values()

# 6. Using pandas to convert to a DataFrame and render.
import pandas as pd
df = pd.DataFrame.from_records(rows)
#creating columns name
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0           Timestamp                  Email Address     Company Name  \
# 1  1/27/2024 14:17:18  mattwilliamanderson@gmail.com  Example Company
#
# 0 Disclaimer 1. Do you have a company wide cyber security policy?  \
# 1    I agree                                                 No
#
# 0 2. Do you have any cyber security awareness posters around the office?  \
# 1                                                Yes
#
# 0 3. Do you have an internal person and/or external company who is responsible for your organisations cyber security?  \
# 1                                                 No
#
# 0 4. How often is cyber security discussed at a management / board level?  \
# 1                                             Rarely
#
# 0 5. Do you currently have cyber insurance?  \
# 1                                       Yes
#
# 0 6. Has your organisation ever experienced a cyber security incident?  ...  \
# 1                                                 No                    ...
#
# 0 45. Do you have a VPN setup for staff to connect to the office remotely?  \
# 1                                                Yes
#
# 0 46. Do you have guidelines for staff to use their personal computers to access your organisations systems and data?  \
# 1                                                 No
#
# 0 47. Do you have a recovery plan of who is responsible for what and who has access to recovery data?  \
# 1                                                Yes
#
# 0 48. Do you perform regular backups of computers and servers?  \
# 1                                                 No
#
# 0 49. Do you test the integrity of backups on a regular basis?  \
# 1                                                Yes
#
# 0 50. Are you aware of what notification is required to send to customers should you experience a breach?  \
# 1                                                Yes
#
# 0 51. Do you maintain computer / server logs to investigate a breach should one occur?  \
# 1                                                 No
#
# 0 52. Do you have a basic plan of action (incident response plan) which outlines roles and responsibilities should you experience a cyber incident?  \
# 1                                                Yes
#
# 0 53. Have you specifically investigated your legal risk relating to cyber security?  \
# 1                                                 No
#
# 0 54. Have you specifically investigated your regulatory obligations with relation to cyber security?
# 1                                                Yes
#
# [1 rows x 57 columns]
# Warning: Total number of columns (57) exceeds max_columns (20) limiting to first (20) columns.
